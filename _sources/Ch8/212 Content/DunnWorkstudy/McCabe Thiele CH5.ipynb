# %% [markdown]
# # Lecture Notes
#
# $$ \require{cancel} $$
#
#
# # 1
#
# **Dunn_WQ23_212**
# _Not for Distribution Beyond Winter 23 212 Students_
#
# - We can solve with trial and error graphically
# - L and V often don't vary that much in a specific region of a column.
# - We can assume:
#
#
#  $L_1$ = $L_2$ = $L_3$...$L$
#
#  $V_1$ = $V_2$ = $V_3$...$V$
#
# $\overline{L}_{N+1}$ ... $\overline{L}_{f}$ = $\overline{L}$
#
# $\overline{V}_{f+1}$ ... $\overline{V}_{N+1}$ = $\overline{V}$

# %% [markdown]
# But $L \neq \overline{L}$ and $V \neq \overline{V}$
#
#
# especially valid  if
#
# - heat of vapor per mol is constant
# - Specific heat change from stage to stage are small compared to latent heat change.
#   - (Stationary heat dominants and it is constant)
#   - H is just a rate of change in mass from \( L = V \) from the liquid to vapor phase.
# - Column is adiabatic.
#
# => **Constant Molar Overflow (CMO)**
# - True for some hydrocarbons at CMO-energy balance satisfied V,L, D don't change -> Then we are left with mass balance VLE and end vapor liquid equilibrium
#
# Go back to overall balance and most volatile component balance
#
# $$ V_{i,j+1} = L_j + D $$
# $$ V_{j+1} y_{j+1} = L_{j} x_{j} + D_{x_D} $$
#
#
# $$ V_{j+1} y_{j+1} = L_{j} x_{j} + (V_{j+1} - L_{j})x_{D} $$
#
#
# To solve for $ y_{j+1} $, the equation is:
#
# $$ y_{j+1} = \frac{L_{j}}{V_{j+1}} x_j + \left(1 - \frac{L_{j}}{V_{j+1}}\right) x_D $$
#
# <div align="center">\( L \) and \( V \) are constant (CMO)</div>
#
#
#
# $$ y_{j+1} = \frac{L_{j}}{V}x_{j} + (1 - \frac{L}{V}) x_{D} $$
#
# - Operating equation
# - Enriching section
#
# What are we relating? composition of <u>passing streams</u>
# Through these quations we are relating the composiong of passing streams

# %% [markdown]
# # 2
#
# Solve sequentially with relationship and equilibrium.
#
# ### Stripping Section:
#
#
# $$
# y_R = \frac{\overline{L}_{R-1}}{V_R} (x_{R-1}) - \left( \frac{\overline{L}_{R-1}}{\overline{V}_R} - 1 \right) x_B
# $$
#
# <div align="center">where $\overline{L}$ and $\overline{V}$ are constants.</div>
#
#
#
# $$
# y_R = (\frac{\overline{L}}{\overline{V}}) x_{R-1} - (\frac{\overline{L}}{\overline{V}}-1)x_B
# $$
#
# <div align="center">stripping section operating equation</div>
#
# Feed has a big influence on the column.
#
# If F mostly
# L, $ \overline{L} > L$
# V, $ V > \overline{V}$
#
# ## Some figure
#
# $ F + \overline{V} + L = \overline{L} + V $
# $ Fh_F + \overline{V}H_{f+1} + Lh_{f-1} = \overline{L}-h_f + VH_? $
#
# under CMO, $H_{f+1} \approx H_f$
# $h_{f-1} \approx h_? $
#
# $Fh_F + (\overline{V} - V)H \approx (\overline{L} - L)h $

# %% [markdown]
# # 3
#
# Start with mass around feed stage:
#
# ## Some figure
#
# $ F + \overline{V} + = \overline{L} + V $
#
# E bal
#
# $ Fh_F + \overline{V}H_{f+1} + ?h_{f-1} = \overline{L}h_f + VH_f $
# - note: could be L, V, or partial L, V
#
# Under CMO, L, and V enthalpies approximately constant from stage to stage.
#
# $ H_{f+1} \approx H_{f} $
# $ h_{p-1} \approx h_{f} $
#
# Simplifying the energy balance:
#
# $ Fh_F + (\overline{V} - V)H \approx(\overline{L} - L)h $
#
# $(\overline{V} - V)$ is key
#
# Solve mass balance for $(\overline{V} - V)$
#
# $
# (\overline{V} - V) = (\overline{V} - V) - F \rightarrow \text{E bal}
# $
#
# ??? Line of crossing out could do if needed ????
#
#
# $ Fh_F + [(\overline{L} - L) - F]H \approx (\overline{L} - L) h $
#
# $ (\overline{L} - L)(H-h) \approx F(H-h_F) $
#
# $
# \frac{\overline{L} - L}{F} \approx \frac{(H - h_F)}{(H-h} \rightarrow \text{Define as q}
# $
#
# we can use enthalpies here to calculate q.
#
#
# $$ \overline{L} = L + F_q $$

# %% [markdown]
# # 4
#
# $q$ is the fraction of feed that is liquid.
#
#
# - $\overline{L} - L$ is amount of <u>new</u> liquid that was in $F$
# - If all L, $ q = 1$ then when we have a saturated liquid
#
# In flash, we also said
# $$q = \frac{L}{F}$$
# $$f = \frac{V}{F}$$
# $$f = 1-q$$
#
#
#
# $f = \frac{V_feed}{F} = \frac{V-\overline{V}}{F} \approx \frac{h_f - h}{H-h} \leftarrow $ estimate and assume CMO
#
# $\overline{V}= V-fF $
#
# $\overline{L} = L + (1-f)F \leftarrow (1-f) = q $
#
# ***
#
# **McCabe Thiele graphical solution method for distillation columns**
#
#
# **Operating Equation in enriching section:**
#
# $$y_{j+1} = \frac{V}{L}x_j + (1 - \frac{L}{V})x_D$$
#
#
#
# $$y = \frac{L}{V}x + (1 - \frac{L}{V})x_D$$
# <div align="center">applies to passing streams like $V_2$ and $L_1$.</div>
#
#
#
# - For this line, at what value of $x$ does $y = x$?
# - $x = \frac{L}{V}x + (1 - \frac{L}{V})x_D$
# - $x(1 - \frac{L}{V}) = (1 - \frac{L}{V})x_D$
# - $x = x_D$
#
# => The top operating line intersects the $y = x$ line at $x = x_D$.

# %% [markdown]
# # 5
#
# ## Some figure
#
# Where does the top operating line intersect $y$ axis?
#
# - $x = D$
# - $y = (1 - \frac{L}{V})x_D$ also, slope in $\frac{L}{V}$
#
# Each time you find a point on the VLE curve, you need another eq. stage.
#
# ***
#
# Takine a look at stripping ?? bottom line
#
# ## Some figure
#
# $y = \frac{\overline{L}}{\overline{V}}x - (\frac{\overline{L}}{\overline{V}} - 1)x_B$
# Where does this op. line intersect the $y = x$ line?
#
# - $x = \frac{L}{V}x - (\frac{L}{V} - 1)x_B$
# - $x = x_B$
#
# $$ \overline{L}_N + \overline{V}_{N+1} \rightarrow \text{mass balance relationship} $$
#
# $$y_k = (\frac{\overline{L}}{\overline{V}})x_{R-1}$$
# $$y_{N+1} = (\frac{\overline{L}}{\overline{V}})x_N$$
#
# ??? theres some box here ???
#
# $y_N$, $y_{N+1}$ must be a point on the operating line.
#
#
# $$y_{k+1} = (\frac{L}{V})x_k$$
# $$y_{n+1} = (\frac{L}{V})x_n$$
#
# $x_{n+1}$ must be a point on the operating line.
#
# ## Some figure
#
# <div align="center">We switch from top to bottom operating line at feed stage.</div>

# %% [markdown]
# # 6
#
# ## Some figure
#
# **Show Fig 4-8A**
#
# Stage 3 is optimal and will result in the fewest number of stages.
#
# 4-8B: went to bottom operating line.
#
# 7 stages.
#
# C $\rightarrow$ too late $\rightarrow$ 7 stages
#
# **Fractional stages** -
#
# $$\frac{\text{distance from operating line to $x_B$}}{\text{distance from operating line to eq curve}} = \frac{A}{B} $$
#
# ## Some figure
#
# Not real—will only have integer number of stages.
#
# **Feed line: We have one last line to add: feed line.**
#
# $$ yV = Lx + Dx_D $$
# <div align="center">with CMO above feed.</div>
#
# $$ y\overline{V} = \overline{V}x - Bx_B $$
# <div align="center">with CMO below feed.</div>
#
# Find intersection of two lines:
#
# $$ y_{\text{top op}} = y_{\text{bot op}} $$
# $$ x_{\text{top op}} = y_{\text{bot op}} $$

# %% [markdown]
# # 7
#
# $$ y(\overline{V}-V) = (\overline{L}-L)x - \frac{(Dx_D + Bx_B)}{-Fz} $$
#
#
# <div align="center">$Fz$ from total column mass bal.</div>
#
#
# To solve for $y$:
#
# $$ y = - \left( \frac{\overline{L} - L}{V - \overline{V}} \right)x + \left( \frac{Fz}{V - \overline{V}} \right) $$
#
#
# <div align="center">Feed equation straight, but op line intersection MUST occur on this line.</div>
#
# <div align="center">For a two-phase feed, we ??? to </div>
# $$\overline{L} - L = L_F$$
# $$V - \overline{V}= V_F$$
#
#
# $$ y = \frac{-L_{F}}{V_{F}}x + \frac{F}{V_{F}}z \rightarrow \text{just like flash distillation! Represents flashing of feed into column}$$
#
# Write as $f = V/F$:
#
# $$ y = \frac{-1-f}{f}x + \frac{1}{f}z $$
# $$ nq = \frac{L_F}{F} \rightarrow y = \frac{q}{q-1}x + \frac{1}{1-q}z $$
#
#
# <div align="center">Can be for any type of feed.</div>
# <div align="center">Can find $q$ from enthalpy of liquid, $q = 1 \rightarrow$ slope is straight</div>
#
# Show Fig 4-10.
#
# All lines run through $y = x$ line:
#
# $$ x = \frac{q}{q - 1} x + \frac{1}{1 - q} z $$
#
# $$ \cancel{\frac{q - 1 - q}{q-1}x} = \cancel{\frac{1}{q-1}}z $$
#
#
# $$x = z \rightarrow \text{just like in flash distillation} $$
